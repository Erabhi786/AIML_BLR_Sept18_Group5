# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline
import os
os.chdir('/content/drive/My Drive/GL_Capstone/')

# %%
i=0
for filename in os.listdir("images"): 
  src =filename.replace('-','') 
  # rename() function will 
  # rename all the files 
  print(src)
  print(filename)
  os.rename(filename, src) 
  i += 1
# Out:
# 085a6486c3b34ca280f1be07d23e853b.jpg
# 085a6486-c3b3-4ca2-80f1-be07d23e853b.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-cff02323380e> in <module>()
#       6   print(src)
#       7   print(filename)
# ----> 8   os.rename(filename, src)
#       9   i += 1
#
# FileNotFoundError: [Errno 2] No such file or directory: '085a6486-c3b3-4ca2-80f1-be07d23e853b.jpg' -> '085a6486c3b34ca280f1be07d23e853b.jpg'
